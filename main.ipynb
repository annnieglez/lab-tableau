# %%
import pandas as pd
url = 'https://raw.githubusercontent.com/data-bootcamp-v4/data/main/we_fn_use_c_marketing_customer_value_analysis.csv'
we_fn_use_c_marketing_customer_value_analysis = pd.read_csv(url)
we_fn_use_c_marketing_customer_value_analysis.reset_index().to_csv('we_fn_use_c_marketing_customer_value_analysis.csv', index=False)

# %%
import data_check as ch

# %%
we_fn_use_c_marketing_customer_value_analysis = pd.read_csv("we_fn_use_c_marketing_customer_value_analysis.csv")
ch.check(we_fn_use_c_marketing_customer_value_analysis)
# Out:
# Number of columns: 25 and rows: 9134
#
# Data types:
# index                              int64
# Customer                          object
# State                             object
# Customer Lifetime Value          float64
# Response                          object
# Coverage                          object
# Education                         object
# Effective To Date                 object
# EmploymentStatus                  object
# Gender                            object
# Income                             int64
# Location Code                     object
# Marital Status                    object
# Monthly Premium Auto               int64
# Months Since Last Claim            int64
# Months Since Policy Inception      int64
# Number of Open Complaints          int64
# Number of Policies                 int64
# Policy Type                       object
# Policy                            object
# Renew Offer Type                  object
# ...
